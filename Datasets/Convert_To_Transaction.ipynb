# %%
import pandas as pd
import datetime as dt
from pandas.tseries.offsets import MonthEnd

# %%
def readCSV(inputCSV):
    df = pd.read_csv(inputCSV)
    display(df)
    
readCSV("Merged_Datasets(date)/Philippine_Monthly.csv")

# %%
def convert_to_diff_dataset(input_csv , output_csv):
    input_df = pd.read_csv(input_csv)
    df = input_df.copy()   
    df["canada_unemployment_rates"] = df["canada_unemployment_rates"].diff()
    df["unemployment_rates"] = df["unemployment_rates"].diff()
    df["canada_inflation_rate"] = df["canada_inflation_rate"].diff()
    df["inflation_rate"] = df["inflation_rate"].diff()
    df["canada_total_cases"] = df["canada_total_cases"].pct_change()
    df["canada_total_tests"] = df["canada_total_tests"].pct_change()
    df["canada_people_fully_vaccinated"] = df["canada_people_fully_vaccinated"].pct_change()
    df["canada_total_deaths"] = df["canada_total_deaths"].pct_change()
    df["canada_reproduction_rate"] = df["canada_reproduction_rate"].diff()
    df["total_cases"] = df["total_cases"].pct_change()
    df["total_tests"] = df["total_tests"].pct_change()
    df["people_fully_vaccinated"] = df["people_fully_vaccinated"].pct_change()
    df["total_deaths"] = df["total_deaths"].pct_change()
    df["reproduction_rate"] = df["reproduction_rate"].diff()
    df.reset_index(drop=True, inplace=True)
    df.to_csv(output_csv , index=True)
    return(df)


France_df = convert_to_diff_dataset("Merged_Datasets(date)/France_Monthly.csv" , "Merged_Datasets(Diff)/France_Monthly_Diff.csv")
Philippine_df = convert_to_diff_dataset("Merged_Datasets(date)/Philippine_Monthly.csv" , "Merged_Datasets(Diff)/Philippine_Monthly_Diff.csv")
SouthKorea_df = convert_to_diff_dataset("Merged_Datasets(date)/SouthKorea_Monthly.csv" , "Merged_Datasets(Diff)/SouthKorea_Monthly_Diff.csv")
China_df = convert_to_diff_dataset("Merged_Datasets(date)/China_Monthly.csv" , "Merged_Datasets(Diff)/China_Monthly_Diff.csv")
India_df = convert_to_diff_dataset("Merged_Datasets(date)/India_Monthly.csv" , "Merged_Datasets(Diff)/India_Monthly_Diff.csv")
display(France_df)
# Out:
#        Date  canada_unemployment_rates  unemployment_rates  \
# 0   2019-01                        NaN                 NaN
# 1   2019-02                        0.0                 0.0
# 2   2019-03                       -0.1                 0.0
# 3   2019-04                        0.0                -0.2
# 4   2019-05                       -0.4                 0.1
# 5   2019-06                        0.1                -0.1
# 6   2019-07                        0.3                -0.2
# 7   2019-08                        0.0                -0.1
# 8   2019-09                       -0.2                -0.1
# 9   2019-10                        0.1                 0.1
# 10  2019-11                        0.3                 0.0
# 11  2019-12                       -0.2                 0.0
# 12  2020-01                       -0.2                 0.0
# 13  2020-02                        0.1                -0.4
# 14  2020-03                        2.2                -0.3
# 15  2020-04                        5.1                 0.1
# 16  2020-05                        0.4                -0.5
# 17  2020-06                       -1.2                 0.4
# 18  2020-07                       -1.3                 1.0
# 19  2020-08                       -0.6                 0.4
# 20  2020-09                       -1.1                 0.0
# 21  2020-10                        0.0                -0.6
# 22  2020-11                       -0.5                -0.2
# 23  2020-12                        0.2                -0.2
# 24  2021-01                        0.5                 0.1
# 25  2021-02                       -1.1                 0.2
# 26  2021-03                       -0.8                 0.0
# 27  2021-04                        0.5                 0.0
# 28  2021-05                        0.0                -0.1
# 29  2021-06                       -0.4                -0.1
# 30  2021-07                       -0.2                -0.1
# 31  2021-08                       -0.3                -0.1
# 32  2021-09                       -0.1                -0.1
# 33  2021-10                       -0.2                -0.2
# 34  2021-11                       -0.7                -0.1
# 35  2021-12                       -0.1                 0.0
# 36  2022-01                        0.5                -0.1
# 37  2022-02                       -1.0                 0.0
# 38  2022-03                       -0.2                 0.1
# 39  2022-04                       -0.1                 0.1
# 40  2022-05                       -0.1                 0.1
# 41  2022-06                       -0.2                 0.0
# 42  2022-07                        0.0                -0.1
# 43  2022-08                        0.5                 NaN
# 44  2022-09                       -0.2                 NaN
# 45  2022-10                        NaN                 NaN
#
#     canada_inflation_rate  inflation_rate  canada_total_cases  \
# 0                     NaN             NaN                 NaN
# 1                     0.1            0.08                 NaN
# 2                     0.4           -0.21                 NaN
# 3                     0.1            0.15                 NaN
# 4                     0.4           -0.32                 NaN
# 5                    -0.4            0.23                 NaN
# 6                     0.0           -0.10                 NaN
# 7                    -0.1           -0.03                 NaN
# 8                     0.0           -0.13                 NaN
# 9                     0.0           -0.15                 NaN
# 10                    0.3            0.27                 NaN
# 11                    0.0            0.43                 NaN
# 12                    0.2            0.03                 NaN
# 13                   -0.2           -0.06            7.250000
# 14                   -1.3           -0.76          323.575758
# 15                   -1.1           -0.34            4.341611
# 16                   -0.2            0.03            0.609169
# 17                    1.1           -0.16            0.136216
# 18                   -0.6            0.58            0.117372
# 19                    0.0           -0.56            0.108721
# 20                    0.4           -0.17            0.254379
# 21                    0.2            0.00            0.463115
# 22                    0.3            0.15            0.612267
# 23                   -0.3           -0.22            0.539239
# 24                    0.3            0.57            0.326410
# 25                    0.1            0.01            0.111264
# 26                    1.1            0.55            0.138663
# 27                    1.2            0.13            0.242129
# 28                    0.2            0.18            0.127231
# 29                   -0.5            0.06            0.023544
# 30                    0.6           -0.33            0.010720
# 31                    0.4            0.72            0.048304
# 32                    0.3            0.29            0.082927
# 33                    0.3            0.46            0.055948
# 34                    0.0            0.16            0.045361
# 35                    0.1           -0.03            0.236648
# 36                    0.3            0.10            0.382203
# 37                    0.6            0.78            0.074422
# 38                    1.0            0.85            0.056780
# 39                    0.1            0.35            0.078871
# 40                    0.9            0.37            0.031604
# 41                    0.4            0.64            0.020126
# 42                   -0.5            0.24            0.032907
# 43                   -0.6           -0.17            0.024964
# 44                   -0.1           -0.36            0.020125
# 45                    NaN             NaN            0.020921
#
#     canada_total_tests  canada_people_fully_vaccinated  canada_total_deaths  \
# 0                  NaN                             NaN                  NaN
# 1                  NaN                             NaN                  NaN
# 2                  NaN                             NaN                  NaN
# 3                  NaN                             NaN                  NaN
# 4                  NaN                             NaN                  NaN
# 5                  NaN                             NaN                  NaN
# 6                  NaN                             NaN                  NaN
# 7                  NaN                             NaN                  NaN
# 8                  NaN                             NaN                  NaN
# 9                  NaN                             NaN                  NaN
# 10                 NaN                             NaN                  NaN
# 11                 NaN                             NaN                  NaN
# 12                 NaN                             NaN                  NaN
# 13                 inf                             NaN                  NaN
# 14          348.643137                             NaN                  NaN
# 15            2.881313                             NaN            25.677632
# 16            1.391414                             NaN             0.930456
# 17            0.748859                             NaN             0.114205
# 18            0.519436                             NaN             0.029695
# 19            0.397609                             NaN             0.018483
# 20            0.374044                             NaN             0.021428
# 21            0.341459                             NaN             0.094509
# 22            0.260168                             NaN             0.195287
# 23            0.258263                             NaN             0.287409
# 24            0.201952                    56881.500000             0.273068
# 25            0.132025                        3.712328             0.097938
# 26            0.130932                        0.328921             0.043874
# 27            0.138717                        0.592030             0.054878
# 28            0.105173                        0.891542             0.054831
# 29            0.056865                        4.495281             0.029278
# 30            0.047887                        0.900676             0.011523
# 31            0.052182                        0.140132             0.012557
# 32            0.068902                        0.058772             0.034530
# 33            0.067500                        0.046728             0.039730
# 34            0.055110                        0.026145             0.024784
# 35            0.078986                        0.013186             0.021288
# 36            0.074531                        0.024697             0.117084
# 37            0.029183                        0.024812             0.080425
# 38            0.021049                        0.008935             0.027409
# 39            0.024819                        0.003935             0.044365
# 40            0.017528                        0.002722             0.044671
# 41            0.002728                        0.001717             0.022746
# 42            0.000000                        0.001437             0.023813
# 43            0.000000                        0.001463             0.028265
# 44            0.000000                        0.001260             0.028439
# 45            0.000000                        0.001836             0.027586
#
#     canada_reproduction_rate  total_cases  total_tests  \
# 0                        NaN          NaN          NaN
# 1                        NaN          NaN          NaN
# 2                        NaN          NaN          NaN
# 3                        NaN          NaN          NaN
# 4                        NaN          NaN          NaN
# 5                        NaN          NaN          NaN
# 6                        NaN          NaN          NaN
# 7                        NaN          NaN          NaN
# 8                        NaN          NaN          NaN
# 9                        NaN          NaN          NaN
# 10                       NaN          NaN          NaN
# 11                       NaN          NaN          NaN
# 12                       NaN          NaN          NaN
# 13                       NaN    19.000000          NaN
# 14                       NaN   521.290000          NaN
# 15                     -0.77     2.231615          NaN
# 16                     -0.17     0.131002          NaN
# 17                      0.09     0.069488     1.609043
# 18                      0.08     0.112613     1.163979
# 19                      0.24     0.411215     0.904867
# 20                      0.06     0.884202     0.755823
# 21                     -0.12     1.329625     0.583862
# 22                     -0.03     0.607863     0.327203
# 23                     -0.06     0.176038     0.338839
# 24                     -0.24     0.216931     0.236196
# 25                      0.16     0.172754     0.194578
# 26                      0.24     0.234067     0.230951
# 27                     -0.26     0.207523     0.164160
# 28                     -0.30     0.009006     0.127616
# 29                      0.06     0.018978     0.094216
# 30                      0.65     0.060533     0.135459
# 31                     -0.15     0.101179     0.201384
# 32                     -0.22     0.038814     0.125916
# 33                     -0.07     0.021762     0.080501
# 34                      0.19     0.070547     0.078128
# 35                      0.42     0.297624     0.169976
# 36                     -0.79     0.916187     0.197898
# 37                      0.14     0.185406     0.054450
# 38                      0.21     0.127997     0.047230
# 39                     -0.30     0.118091     0.039804
# 40                      0.05     0.030459     0.019710
# 41                      0.29     0.053120     0.000000
# 42                     -0.16     0.086816     0.000000
# 43                     -0.01     0.021952     0.000000
# 44                      0.10     0.024921     0.000000
# 45                       NaN     0.040116     0.000000
#
#     people_fully_vaccinated  total_deaths  reproduction_rate
# 0                       NaN           NaN                NaN
# 1                       NaN           NaN                NaN
# 2                       NaN           NaN                NaN
# 3                       NaN           NaN                NaN
# 4                       NaN           NaN                NaN
# 5                       NaN           NaN                NaN
# 6                       NaN           NaN                NaN
# 7                       NaN           NaN                NaN
# 8                       NaN           NaN                NaN
# 9                       NaN           NaN                NaN
# 10                      NaN           NaN                NaN
# 11                      NaN           NaN                NaN
# 12                      NaN           NaN                NaN
# 13                      NaN           NaN                NaN
# 14                      NaN   1762.000000                NaN
# 15                      NaN      5.905559              -0.88
# 16                      NaN      0.183005               0.59
# 17                      NaN      0.036140              -0.16
# 18                      NaN      0.014139               0.30
# 19                      NaN      0.012488              -0.01
# 20                      NaN      0.043236              -0.22
# 21                      NaN      0.150981               0.18
# 22                      NaN      0.433312              -0.60
# 23                      NaN      0.225641               0.37
# 24             26813.000000      0.176737              -0.05
# 25                29.707485      0.136337               0.01
# 26                 0.771899      0.106583               0.07
# 27                 1.255397      0.092783              -0.30
# 28                 0.724341      0.047987              -0.03
# 29                 0.865949      0.014296               0.20
# 30                 0.531262      0.007155               0.32
# 31                 0.247764      0.023037              -0.48
# 32                 0.102098      0.019601              -0.01
# 33                 0.033697      0.008481               0.34
# 34                 0.025696      0.012539               0.26
# 35                 0.049914      0.038694               0.15
# 36                 0.040658      0.058204              -0.67
# 37                 0.017822      0.056675              -0.15
# 38                 0.003449      0.028215               0.40
# 39                 0.001523      0.025692              -0.43
# 40                 0.001263      0.016418               0.21
# 41                 0.001192      0.008127               0.48
# 42                 0.001134      0.016377              -0.70
# 43                 0.000519      0.013877               0.25
# 44                 0.000403      0.006610               0.33
# 45                 0.000345      0.012128                NaN

# %%
def unemploy_rates_cons(canada_unem_rates , unem_rates):
    df_1 = pd.DataFrame()
    df_1.insert(0, "canada_unemployment_rates_value", canada_unem_rates)
    df_1["canada_unemployment_rates"] = False
    df_1.loc[df_1['canada_unemployment_rates_value'] > 0, ["canada_unemployment_rates"]] = True
    df_1.pop("canada_unemployment_rates_value")
    
    df_2 = pd.DataFrame()
    df_2.insert(0, "unemployment_rates_value", unem_rates)
    df_2["unemployment_rates"] = False
    df_2.loc[df_2['unemployment_rates_value'] > 0, ["unemployment_rates"]] = True
    df_1.insert(1, "unemployment_rates", df_2["unemployment_rates"])   
    
    #df_1.insert(3, "unemployment_rates_value", df_2["unemployment_rates_value"])   
    #display(df_1)
    return (df_1)

def inflat_rates_cons(canada_inflat_rates , inflat_rates):
    df_1 = pd.DataFrame()
    df_1.insert(0, "canada_inflation_rate_value", canada_inflat_rates)
    df_1["canada_inflation_rate"] = False
    df_1.loc[df_1['canada_inflation_rate_value'] > 0, ["canada_inflation_rate"]] = True
    df_1.pop("canada_inflation_rate_value")
    
    df_2 = pd.DataFrame()
    df_2.insert(0, "inflation_rate_value", inflat_rates)
    df_2["inflation_rate"] = False
    df_2.loc[df_2['inflation_rate_value'] > 0, ["inflation_rate"]] = True
    df_1.insert(1, "inflation_rate", df_2["inflation_rate"])   
      
    #display(df_1)
    return (df_1)

def covid_info_cons1(can_total_cases , total_cases , can_total_tests , total_tests , can_ppl_vac , ppl_vac):
    df_1 = pd.DataFrame()
    df_1.insert(0, "canada_total_cases_value", can_total_cases)
    df_1["canada_total_cases"] = False
    df_1.loc[df_1['canada_total_cases_value'] > 0, ["canada_total_cases"]] = True
    df_1.pop("canada_total_cases_value")
    
    df_2 = pd.DataFrame()
    df_2.insert(0, "total_cases_value", total_cases)
    df_2["total_cases"] = False
    df_2.loc[df_2['total_cases_value'] > 0, ["total_cases"]] = True
    df_1.insert(1, "total_cases", df_2["total_cases"])   
    
    df_3 = pd.DataFrame()
    df_3 = df_3.astype(bool)  
    df_3.insert(0, "canada_total_tests_value", can_total_tests)
    df_3["canada_total_tests"] = False
    df_3.loc[df_3['canada_total_tests_value'] > 0, ["canada_total_tests"]] = True
    df_1.insert(1, "canada_total_tests", df_3["canada_total_tests"])   
    
    df_4 = pd.DataFrame() 
    df_4.insert(0, "total_tests_value", total_tests)
    df_4["total_tests"] = False
    df_4.loc[df_4['total_tests_value'] > 0, ["total_tests"]] = True
    df_1.insert(1, "total_tests", df_4["total_tests"])   
    
    df_5 = pd.DataFrame() 
    df_5.insert(0, "canada_people_fully_vaccinated_value", can_ppl_vac)
    df_5["canada_people_fully_vaccinated"] = False
    df_5.loc[df_5['canada_people_fully_vaccinated_value'] > 0, ["canada_people_fully_vaccinated"]] = True
    df_1.insert(1, "canada_people_fully_vaccinated", df_5["canada_people_fully_vaccinated"])  
    
    df_6 = pd.DataFrame()
    df_6.insert(0, "people_fully_vaccinated_value", can_ppl_vac)
    df_6["people_fully_vaccinated"] = False
    df_6.loc[df_6['people_fully_vaccinated_value'] > 0, ["people_fully_vaccinated"]] = True
    df_1.insert(1, "people_fully_vaccinated", df_6["people_fully_vaccinated"])
    
    #display(df_1)
    return (df_1)

def covid_info_cons2(can_total_death , total_death , can_repro_rates , repro_rates):
    df_1 = pd.DataFrame() 
    df_1.insert(0, "canada_total_deaths_value", can_total_death)
    df_1["canada_total_deaths"] = False
    df_1.loc[df_1['canada_total_deaths_value'] > 0, ["canada_total_deaths"]] = True
    df_1.pop("canada_total_deaths_value")
    
    df_2 = pd.DataFrame()  
    df_2.insert(0, "total_deaths_value", total_death)
    df_2["total_deaths"] = False
    df_2.loc[df_2['total_deaths_value'] > 0, ["total_deaths"]] = True
    df_1.insert(1, "total_deaths", df_2["total_deaths"]) 
    
    df_3 = pd.DataFrame() 
    df_3.insert(0, "canada_reproduction_rate_value", can_repro_rates)
    df_3["canada_reproduction_rate"] = False
    df_3.loc[df_3['canada_reproduction_rate_value'] > 0, ["canada_reproduction_rate"]] = True
    df_1.insert(1, "canada_reproduction_rate", df_3["canada_reproduction_rate"])   
    
    df_4 = pd.DataFrame() 
    df_4.insert(0, "reproduction_rate_value", repro_rates)
    df_4["reproduction_rate"] = False
    df_4.loc[df_4['reproduction_rate_value'] > 0, ["reproduction_rate"]] = True
    df_1.insert(1, "reproduction_rate", df_4["reproduction_rate"])   

    #display(df_1)
    return (df_1)

def convert_to_transaction(inputCSV , outputCSV):
    input_df = pd.read_csv(inputCSV)
    input_df = input_df.iloc[1: , :]  #delete first row
    df = pd.DataFrame()

    unemploy_df = unemploy_rates_cons(input_df["canada_unemployment_rates"] , input_df["unemployment_rates"] )
    df["canada_unemployment_rates"] = unemploy_df["canada_unemployment_rates"]
    df["unemployment_rates"] = unemploy_df["unemployment_rates"]
    
    inflat_df = inflat_rates_cons(input_df["canada_inflation_rate"] , input_df["inflation_rate"])
    df["canada_inflation_rate"] = inflat_df["canada_inflation_rate"]
    df["inflation_rate"] = inflat_df["inflation_rate"]
    
    covid_info1_df = covid_info_cons1(input_df["canada_total_cases"] , input_df["total_cases"] , input_df["canada_total_tests"] , input_df["total_tests"] , input_df["canada_people_fully_vaccinated"] , input_df["people_fully_vaccinated"])
    df["canada_total_cases"] = covid_info1_df["canada_total_cases"]
    df["total_cases"] = covid_info1_df["total_cases"]
    df["canada_total_tests"] = covid_info1_df["canada_total_tests"]
    df["total_tests"] = covid_info1_df["total_tests"]
    df["canada_people_fully_vaccinated"] = covid_info1_df["canada_people_fully_vaccinated"]
    df["people_fully_vaccinated"] = covid_info1_df["people_fully_vaccinated"]
    
    covid_info2_df = covid_info_cons2(input_df["canada_total_deaths"] , input_df["total_deaths"] , input_df["canada_reproduction_rate"] , input_df["reproduction_rate"])
    df["canada_total_deaths"] = covid_info2_df["canada_total_deaths"]
    df["total_deaths"] = covid_info2_df["total_deaths"]
    df["canada_reproduction_rate"] = covid_info2_df["canada_reproduction_rate"]
    df["reproduction_rate"] = covid_info2_df["reproduction_rate"]
    
    #df["Transaction ID"] = df.index
    #first_column = df.pop('Transaction ID')
    #df.insert(0, 'Transaction ID', first_column)    
    #display(df)
    
    df.reset_index(drop=True, inplace=True)
    df.to_csv(outputCSV , index=False)
    return(df)

convert_to_transaction("Merged_Datasets(Diff)/India_Monthly_Diff.csv" , "Transaction_Datasets/India_Monthly_Diff.csv")
convert_to_transaction("Merged_Datasets(Diff)/France_Monthly_Diff.csv" , "Transaction_Datasets/France_Monthly_Diff.csv")
convert_to_transaction("Merged_Datasets(Diff)/SouthKorea_Monthly_Diff.csv" , "Transaction_Datasets/SouthKorea_Monthly_Diff.csv")
convert_to_transaction("Merged_Datasets(Diff)/Philippine_Monthly_Diff.csv" , "Transaction_Datasets/Philippine_Monthly_Diff.csv")
convert_to_transaction("Merged_Datasets(Diff)/China_Monthly_Diff.csv" , "Transaction_Datasets/China_Monthly_Diff.csv")
# Out:
#     canada_unemployment_rates  unemployment_rates  canada_inflation_rate  \
# 0                       False                True                   True
# 1                       False               False                   True
# 2                       False               False                   True
# 3                       False               False                   True
# 4                        True                True                  False
# 5                        True                True                  False
# 6                       False               False                  False
# 7                       False               False                  False
# 8                        True               False                  False
# 9                        True               False                   True
# 10                      False                True                  False
# 11                      False                True                   True
# 12                       True                True                  False
# 13                       True               False                  False
# 14                       True                True                  False
# 15                       True               False                  False
# 16                      False               False                   True
# 17                      False               False                  False
# 18                      False               False                  False
# 19                      False               False                   True
# 20                      False               False                   True
# 21                      False               False                   True
# 22                       True               False                  False
# 23                       True                True                   True
# 24                      False                True                   True
# 25                      False               False                   True
# 26                       True               False                   True
# 27                      False               False                   True
# 28                      False               False                  False
# 29                      False                True                   True
# 30                      False               False                   True
# 31                      False               False                   True
# 32                      False               False                   True
# 33                      False                True                  False
# 34                      False                True                   True
# 35                       True                True                   True
# 36                      False                True                   True
# 37                      False                True                   True
# 38                      False                True                   True
# 39                      False               False                   True
# 40                      False               False                   True
# 41                      False               False                  False
# 42                       True               False                  False
# 43                      False                True                  False
# 44                      False               False                  False
#
#     inflation_rate  canada_total_cases  total_cases  canada_total_tests  \
# 0            False               False        False               False
# 1             True               False        False               False
# 2             True               False        False               False
# 3             True               False        False               False
# 4            False               False        False               False
# 5             True               False        False               False
# 6             True               False        False               False
# 7             True               False        False               False
# 8             True               False        False               False
# 9             True               False        False               False
# 10           False               False        False               False
# 11            True               False        False               False
# 12           False                True         True                True
# 13           False                True         True                True
# 14           False                True         True                True
# 15           False                True         True                True
# 16            True                True         True                True
# 17            True                True         True                True
# 18           False                True         True                True
# 19           False                True         True                True
# 20           False                True         True                True
# 21           False                True         True                True
# 22            True                True         True                True
# 23           False                True         True                True
# 24            True                True         True                True
# 25            True                True         True                True
# 26            True                True         True                True
# 27            True                True         True                True
# 28           False                True         True                True
# 29           False                True         True                True
# 30           False                True         True                True
# 31           False                True         True                True
# 32            True                True         True                True
# 33            True                True         True                True
# 34           False                True         True                True
# 35           False                True         True                True
# 36           False                True         True                True
# 37            True                True         True                True
# 38            True                True         True                True
# 39           False                True         True                True
# 40            True                True         True               False
# 41            True                True         True               False
# 42           False                True         True               False
# 43            True                True         True               False
# 44           False                True         True               False
#
#     total_tests  canada_people_fully_vaccinated  people_fully_vaccinated  \
# 0         False                           False                    False
# 1         False                           False                    False
# 2         False                           False                    False
# 3         False                           False                    False
# 4         False                           False                    False
# 5         False                           False                    False
# 6         False                           False                    False
# 7         False                           False                    False
# 8         False                           False                    False
# 9         False                           False                    False
# 10        False                           False                    False
# 11        False                           False                    False
# 12        False                           False                    False
# 13        False                           False                    False
# 14        False                           False                    False
# 15        False                           False                    False
# 16        False                           False                    False
# 17        False                           False                    False
# 18        False                           False                    False
# 19        False                           False                    False
# 20        False                           False                    False
# 21        False                           False                    False
# 22        False                           False                    False
# 23        False                            True                     True
# 24        False                            True                     True
# 25        False                            True                     True
# 26        False                            True                     True
# 27        False                            True                     True
# 28        False                            True                     True
# 29        False                            True                     True
# 30        False                            True                     True
# 31        False                            True                     True
# 32        False                            True                     True
# 33        False                            True                     True
# 34        False                            True                     True
# 35        False                            True                     True
# 36        False                            True                     True
# 37        False                            True                     True
# 38        False                            True                     True
# 39        False                            True                     True
# 40        False                            True                     True
# 41        False                            True                     True
# 42        False                            True                     True
# 43        False                            True                     True
# 44        False                            True                     True
#
#     canada_total_deaths  total_deaths  canada_reproduction_rate  \
# 0                 False         False                     False
# 1                 False         False                     False
# 2                 False         False                     False
# 3                 False         False                     False
# 4                 False         False                     False
# 5                 False         False                     False
# 6                 False         False                     False
# 7                 False         False                     False
# 8                 False         False                     False
# 9                 False         False                     False
# 10                False         False                     False
# 11                False         False                     False
# 12                False          True                     False
# 13                False          True                     False
# 14                 True          True                     False
# 15                 True          True                     False
# 16                 True         False                      True
# 17                 True         False                      True
# 18                 True         False                      True
# 19                 True         False                      True
# 20                 True         False                     False
# 21                 True         False                     False
# 22                 True         False                     False
# 23                 True          True                     False
# 24                 True         False                      True
# 25                 True         False                      True
# 26                 True         False                     False
# 27                 True         False                     False
# 28                 True         False                      True
# 29                 True         False                      True
# 30                 True         False                     False
# 31                 True         False                     False
# 32                 True         False                     False
# 33                 True         False                      True
# 34                 True         False                      True
# 35                 True         False                     False
# 36                 True         False                      True
# 37                 True          True                      True
# 38                 True          True                     False
# 39                 True          True                      True
# 40                 True         False                      True
# 41                 True         False                     False
# 42                 True         False                     False
# 43                 True         False                      True
# 44                 True         False                     False
#
#     reproduction_rate
# 0               False
# 1               False
# 2               False
# 3               False
# 4               False
# 5               False
# 6               False
# 7               False
# 8               False
# 9               False
# 10              False
# 11              False
# 12              False
# 13               True
# 14              False
# 15               True
# 16               True
# 17               True
# 18              False
# 19               True
# 20               True
# 21               True
# 22              False
# 23              False
# 24               True
# 25               True
# 26              False
# 27               True
# 28              False
# 29               True
# 30              False
# 31               True
# 32               True
# 33               True
# 34              False
# 35              False
# 36               True
# 37              False
# 38              False
# 39              False
# 40               True
# 41              False
# 42               True
# 43              False
# 44              False
