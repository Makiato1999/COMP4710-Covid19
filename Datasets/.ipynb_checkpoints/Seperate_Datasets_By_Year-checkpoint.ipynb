# %%
import pandas as pd
import datetime as dt
from pandas.tseries.offsets import MonthEnd

# %% [markdown]
# ## seperate the datasets into 4 datasets by years

# %%
def seperate_datasets(country):
    inputCSV = "Merged_Datasets(Diff)/"+country+"_Monthly_Diff.csv"
    outputCSV_2019 = "Merged_Diff_Datasets(Seperate)/"+country+"_Monthly_Diff_2019.csv"
    outputCSV_2020 = "Merged_Diff_Datasets(Seperate)/"+country+"_Monthly_Diff_2020.csv"
    outputCSV_2021 = "Merged_Diff_Datasets(Seperate)/"+country+"_Monthly_Diff_2021.csv"
    outputCSV_2022 = "Merged_Diff_Datasets(Seperate)/"+country+"_Monthly_Diff_2022.csv"
    
    df = pd.read_csv(inputCSV)
    df_1 = df.copy()
    del df_1["Unnamed: 0"]
    #df_1 = df_1.drop([12,40], axis=0, inplace=True)
    display(df_1)
    
    
seperate_datasets("India")
# Out:
#        Date  canada_unemployment_rates  unemployment_rates  \
# 0   2019-01                        NaN                 NaN
# 1   2019-02                        0.0                0.34
# 2   2019-03                       -0.1               -0.55
# 3   2019-04                        0.0                0.70
# 4   2019-05                       -0.4               -0.32
# 5   2019-06                        0.1                0.84
# 6   2019-07                        0.3               -0.53
# 7   2019-08                        0.0                0.85
# 8   2019-09                       -0.2               -1.05
# 9   2019-10                        0.1                0.96
# 10  2019-11                        0.3               -0.87
# 11  2019-12                       -0.2                0.37
# 12  2020-01                       -0.2               -0.38
# 13  2020-02                        0.1                0.54
# 14  2020-03                        2.2                0.99
# ...
