# %%
import pandas as pd
import datetime as dt

# %%
csv = 'Merged_Datasets/France_Monthly.csv'
df = pd.read_csv(csv)

df.head()
# Out:
#    Year  Month  canada_unemployment_rates  unemployment_rates  \
# 0  2019      1                        5.9                 8.7
# 1  2019      2                        5.9                 8.7
# 2  2019      3                        5.8                 8.7
# 3  2019      4                        5.8                 8.5
# 4  2019      5                        5.4                 8.6
#
#    canada_inflation_rate  inflation_rate  canada_total_cases  \
# 0                    1.4            1.24                 NaN
# 1                    1.5            1.32                 NaN
# 2                    1.9            1.11                 NaN
# 3                    2.0            1.26                 NaN
# 4                    2.4            0.94                 NaN
#
#    canada_total_tests  canada_people_fully_vaccinated  canada_total_deaths  \
# 0                 NaN                             NaN                  NaN
# ...

# %%
df['Date'] = pd.to_datetime(df[['Year', 'Month']].assign(DAY=1))
df['Date'] = df['Date'].apply(lambda x: x.strftime('%Y-%m'))
df.head()
# Out:
#    Year  Month  canada_unemployment_rates  unemployment_rates  \
# 0  2019      1                        5.9                 8.7
# 1  2019      2                        5.9                 8.7
# 2  2019      3                        5.8                 8.7
# 3  2019      4                        5.8                 8.5
# 4  2019      5                        5.4                 8.6
#
#    canada_inflation_rate  inflation_rate  canada_total_cases  \
# 0                    1.4            1.24                 NaN
# 1                    1.5            1.32                 NaN
# 2                    1.9            1.11                 NaN
# 3                    2.0            1.26                 NaN
# 4                    2.4            0.94                 NaN
#
#    canada_total_tests  canada_people_fully_vaccinated  canada_total_deaths  \
# 0                 NaN                             NaN                  NaN
# ...
